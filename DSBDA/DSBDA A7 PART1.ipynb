# %% [markdown]
# **Text Analytics**

# %%
pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2022.10.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.65.0)

# %%
import nltk

# %% [markdown]
# **Download the required packages**

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %% [markdown]
# **Initialize the text**

# %%
text= "Tokenization is the first step in text analytics The process of breaking down a text paragraph into smaller chunkssuch as words or sentences is called Tokenization."

# %% [markdown]
# **Perform Tokenization**

# %%
#Sentence Tokenization
from nltk.tokenize import sent_tokenize
tokenized_text= sent_tokenize(text)
print(tokenized_text)
#Word Tokenization
from nltk.tokenize import word_tokenize
tokenized_word=word_tokenize(text)
print(tokenized_word)
# Out:
# ['Tokenization is the first step in text analytics The process of breaking down a text paragraph into smaller chunkssuch as words or sentences is called Tokenization.']
# ['Tokenization', 'is', 'the', 'first', 'step', 'in', 'text', 'analytics', 'The', 'process', 'of', 'breaking', 'down', 'a', 'text', 'paragraph', 'into', 'smaller', 'chunkssuch', 'as', 'words', 'or', 'sentences', 'is', 'called', 'Tokenization', '.']

# %%
import re
re.compile('<title>(.*)</title>')
# Out:
# re.compile(r'<title>(.*)</title>', re.UNICODE)

# %% [markdown]
# **Removing Punctuations and Stop Word**

# %%
from nltk.sem.logic import Expression
# print stop words of English
from nltk.corpus import stopwords
stop_words=set(stopwords.words("english"))
print(stop_words)
text= "How to remove stop words with NLTK library in Python?"
text= re.sub('[^a-zA-Z]', ' ',text)
tokens = word_tokenize(text.lower())
filtered_text=[]
for w in tokens:
   if w not in stop_words:
      filtered_text.append(w)
print("Tokenized Sentence:",tokens)
print("Filterd Sentence:",filtered_text)
# Out:
# {'will', "weren't", 'o', 'doing', 'ours', "hasn't", "needn't", "mightn't", "you'll", 'mightn', "you've", 'but', 'that', 'further', 'as', 'yourselves', 'which', 'it', 'don', 'for', "isn't", 'any', 'our', 'off', 'shan', 'about', 'more', 'at', 'be', 'before', 'there', "don't", 'me', 'each', 'when', 'once', 'being', 't', 'an', 'yourself', 'with', 'won', 'what', 'between', 'hadn', 'y', "hadn't", 'while', 'than', "couldn't", 'weren', 'nor', 'her', "wouldn't", 'itself', 'on', 'during', "should've", 'him', 'd', 'm', 'own', 'were', "wasn't", 'he', 'we', 'hers', 'then', 'was', "doesn't", 'too', 'been', 'those', "haven't", 'wouldn', 'their', 'did', 'such', 'had', 'his', 'shouldn', 'll', 'himself', 'no', 'so', 'themselves', 'and', 'now', 'below', "you're", 'am', "she's", 'this', 'having', 'if', 'again', 'most', 'ma', 'ourselves', 'why', 'all', 'some', 'theirs', 'is', 'haven', 'after', "you'd", 'these', 'through', 'up', 'needn', 'in', 'doesn', 'the', 'very', "shan't", 'whom', 'should', 'because', 'mustn', 'has', 'here', 'same', "aren't", 'down', "didn't", 'where', 'you', 'until', 'i', "it's", 'who', 'not', 'just', 'ain', "won't", 'into', 'only', 'they', 'against', "mustn't", 'few', 'over', 'wasn', 'other', 'she', 'its', "shouldn't", 'hasn', 'myself', "that'll", 'out', 'does', 'aren', 'didn', 'your', 'isn', 'of', 's', 've', 'have', 'how', 'to', 'by', 'or', 're', 'yours', 'are', 'from', 'under', 'herself', 'couldn', 'do', 'them', 'above', 'can', 'a', 'both', 'my'}
# Tokenized Sentence: ['how', 'to', 'remove', 'stop', 'words', 'with', 'nltk', 'library', 'in', 'python']
# Filterd Sentence: ['remove', 'stop', 'words', 'nltk', 'library', 'python']

# %% [markdown]
# **Perform Stemming**

# %%
from nltk.stem import PorterStemmer
e_words= ["wait", "waiting", "waited", "waits"]
ps =PorterStemmer()
for w in e_words:
    rootWord=ps.stem(w)
print(rootWord)
# Out:
# wait

# %% [markdown]
# **Perform Lemmatization**

# %%
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()
text = "studies studying cries cry"
tokenization = nltk.word_tokenize(text)
for w in tokenization:
    print("Lemma for {} is {}".format(w,
wordnet_lemmatizer.lemmatize(w)))
# Out:
# Lemma for studies is study
# Lemma for studying is studying
# Lemma for cries is cry
# Lemma for cry is cry

# %%
import nltk
from nltk.tokenize import word_tokenize
data="The pink sweater fit her perfectly"
words=word_tokenize(data)
for word in words:
    print(nltk.pos_tag([word]))
# Out:
# [('The', 'DT')]
# [('pink', 'NN')]
# [('sweater', 'NN')]
# [('fit', 'NN')]
# [('her', 'PRP$')]
# [('perfectly', 'RB')]
